# %%
#Importanto bibliotecas
import pandas as pd

# %%
df= pd.read_excel('201710_EmissaoPassagens_SCDP (1).xlsx',skiprows=3,skip_footer=3)

# %%
df
# Out:
#         Código do órgão superior  \
# 0                              3
# 1                              3
# 2                              3
# 3                              3
# 4                              3
# 5                              3
# 6                              3
# 7                              3
# 8                              3
# 9                              3
# 10                             3
# 11                             3
# 12                             3
# 13                             3
# 14                             3
# 15                             3
# 16                             3
# 17                             3
# 18                             3
# 19                             3
# 20                             3
# 21                             3
# 22                             3
# 23                             3
# 24                             3
# 25                             3
# 26                             3
# ...

# %%
df.columns=df.columns.str.strip()

# %%
df.tail()
# Out:
#        Código do órgão superior  \
# 50400                    219924
# 50401                    219924
# 50402                    219924
# 50403                    219924
# 50404                    219924
#
#                                   Nome do órgão superior  \
# 50400   Secretaria-Geral da Presidência da República ...
# 50401   Secretaria-Geral da Presidência da República ...
# 50402   Secretaria-Geral da Presidência da República ...
# 50403   Secretaria-Geral da Presidência da República ...
# 50404   Secretaria-Geral da Presidência da República ...
#
#        Código do órgão solicitante da viagem  \
# 50400                                  84010
# 50401                                  84010
# 50402                                  84010
# 50403                                  34889
# 50404                                  34889
#
#                      Nome do órgão solicitante da viagem          N. PCDP  \
# ...

# %%
#informações das variaveis do banco
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50405 entries, 0 to 50404
# Data columns (total 23 columns):
# Código do órgão superior                 50405 non-null int64
# Nome do órgão superior                   50405 non-null object
# Código do órgão solicitante da viagem    50405 non-null int64
# Nome do órgão solicitante da viagem      50405 non-null object
# N. PCDP                                  50405 non-null object
# N. Reserva/Localizador                   50405 non-null object
# Data Emissão Bilhete                     50405 non-null object
# Data Embarque                            50405 non-null object
# Valor Tarifa Comercial                   50405 non-null float64
# Percentual Desconto Aplicado             50405 non-null float64
# Valor Tarifa Governo                     50405 non-null float64
# Valor Tarifa Embarque                    50405 non-null float64
# Valor Bilhete                            50405 non-null float64
# ...

# %%
#resumo - estatisticas
df.describe()
# Out:
#        Código do órgão superior  Código do órgão solicitante da viagem  \
# count              50405.000000                           50405.000000
# mean               16489.825176                           47696.792084
# std                36709.186923                           50214.945925
# min                    3.000000                         -122771.000000
# 25%                  315.000000                            3418.000000
# 50%                  471.000000                           32207.000000
# 75%                 2207.000000                           86558.000000
# max               219924.000000                          224227.000000
#
#        Valor Tarifa Comercial  Percentual Desconto Aplicado  \
# count            50405.000000                  50405.000000
# mean               678.273258                      2.078992
# std                432.242664                      3.211066
# min                  0.000000                     -6.640000
# ...

# %%
###################################Analise univarida: Companhias Aereas###############################################

# %%
#tabela de frequencias 
df["Companhia Aérea"].value_counts()
# Out:
#  GOL Linhas Aéreas Inteligentes           17568
#  LATAM AIRLINES BRASIL                    12301
#  AZUL LINHAS AÉREAS BRASILEIRA            10967
#  AVIANCA S.A.                              9028
#  MAP TRANSPORTES AEREOS LTDA - MAP          274
#  Gol OU Latam - Parceria com Terceiro       267
# Name: Companhia Aérea, dtype: int64

# %%
#trabalhando com graficos
import seaborn as sns

# %%
plt.figure(figsize=(15,7))
sns.countplot(x="Companhia Aérea", data=df)

# %%
#####################################Analise univarida: Valor Tarifa Comercial#########################################

# %%
#Calculo de medidas de tendencia central
#média
print(df['Valor Tarifa Comercial'].mean())
# Out:
# 678.2732582082239

# %%
#maximo e minimo valor da tarifa comercial
print(df['Valor Tarifa Comercial'].max())
print(df['Valor Tarifa Comercial'].min())

# %%
#Calculo de medidas de tendencia de dispersão
#variancia
print(df['Valor Tarifa Comercial'].std())
# Out:
# 432.2426641770543

# %%
#trabalhando com graficos

# %%
plt.figure(figsize=(15,7))
df.boxplot(column='Valor Tarifa Comercial')

# %%
################################ ANALISE BIVARIADA: "Companhia Aérea" E 'Voos Cancelados'########################

# %%
#TABELA DE CONTIGENCIA 
pd.crosstab(df["Companhia Aérea"],df['Cancelado'],margins=True)
# Out:
# Cancelado                                Não          Sim           All
# Companhia Aérea
#  AVIANCA S.A.                                  8601          427   9028
#  AZUL LINHAS AÉREAS BRASILEIRA                10514          453  10967
#  GOL Linhas Aéreas Inteligentes               16830          738  17568
#  Gol OU Latam - Parceria com Terceiro           239           28    267
#  LATAM AIRLINES BRASIL                        11766          535  12301
#  MAP TRANSPORTES AEREOS LTDA - MAP              267            7    274
# All                                           48217         2188  50405

# %%
################################ ANALISE BIVARIADA: "Companhia Aérea" E 'Remarcado'########################

# %%
pd.crosstab(df["Companhia Aérea"],df['Remarcado'],margins=True)
# Out:
# Remarcado                                Não          Sim           All
# Companhia Aérea
#  AVIANCA S.A.                                  9025            3   9028
#  AZUL LINHAS AÉREAS BRASILEIRA                10962            5  10967
#  GOL Linhas Aéreas Inteligentes               17558           10  17568
#  Gol OU Latam - Parceria com Terceiro           267            0    267
#  LATAM AIRLINES BRASIL                        12301            0  12301
#  MAP TRANSPORTES AEREOS LTDA - MAP              274            0    274
# All                                           50387           18  50405

# %%
################################ ANALISE BIVARIADA: "Companhia Aérea" E 'Valor Tarifa Comercial########################

# %%
plt.figure(figsize=(15,7))
sns.boxplot('Companhia Aérea', 'Valor Tarifa Comercial', data=df);

# %%
################################ ANALISE BIVARIADA: "Companhia Aérea" E 'Situação Final Bilhete########################

# %%
pd.crosstab(df["Companhia Aérea"],df['Situação Final Bilhete'],margins=True)
# Out:
# Situação Final Bilhete                   Andamento   Cancelado   Voado    All
# Companhia Aérea
#  AVIANCA S.A.                                 3025         427    5576   9028
#  AZUL LINHAS AÉREAS BRASILEIRA                4014         453    6500  10967
#  GOL Linhas Aéreas Inteligentes               6351         738   10479  17568
#  Gol OU Latam - Parceria com Terceiro          239          28       0    267
#  LATAM AIRLINES BRASIL                        6064         535    5702  12301
#  MAP TRANSPORTES AEREOS LTDA - MAP             267           7       0    274
# All                                          19960        2188   28257  50405

# %%
#visualizando graficamente 
plt.figure(figsize=(15,7))
table = pd.crosstab(df["Companhia Aérea"],df['Situação Final Bilhete'],margins=True)
table.plot(kind='bar',width=1.0, color=['red','yellow','orange','blue','green'], title='Condition by Bedrooms' ,grid=False)

# %%
#visualizando graficamente, outra forma.
plt.figure(figsize=(15,7))
sns.countplot(x="Companhia Aérea",hue='Situação Final Bilhete', data=df)
